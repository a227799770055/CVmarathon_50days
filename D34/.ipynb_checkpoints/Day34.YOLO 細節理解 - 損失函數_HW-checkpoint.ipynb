# %% [markdown]
# ## Day34.YOLO 細節理解 - 損失函數
# 今天的課程，我們講述了
# * 損失函數是描述模型預測出來的結果和實際的差異的依據
# * YOLO 損失函數的設計包含物件位置的定位與物件類別辨識
# * YOLO損失函數透過超參數設定模型有不同的辨識能力

# %% [markdown]
# ### 作業
# 仔細觀察，bbox 寬高計算損失方式和bbox中心計算損失方式有哪邊不一樣嗎? 為什麼要有不同的設計?
# ![title](loss function.png)

# %%
'''
中心計算方式為平方相減
寬高為開根號後相減

小物體計算後的誤差相較於大物體較大，讓小物體有更好的偵測能力
'''
# Out:
# '\n你的答案\n'

# %%
import matplotlib.pyplot as plt

fig=plt.imread('/Users/kuangtinghsiao/python/CVMalason100/D34/HW_answer.png')
plt.imshow(fig)
